# %%
a=99;

if a<100 :
  print("100보다 작다.")

print("=====================================")

a = 200

if a<100 :
  print("a가 100보다 작습니다.")
  print("거짓이므로 안보이겠죠?")

print("프로그램 끝")


a=200;

if a<100:
  print("100보다 작다....")
else :
  print("100보다 크다")

print("=====================================")
a = 77

if a>50:
  if a>75 : 
    print("a는 75보다 크다")
  else :
    print("a는 50보다는 크고 75보다 작다")
else:
  print("a가 50보다 작다...")
# Out:
# 100보다 작다.
# ...
# 프로그램 끝
# 100보다 크다
# ...
# a는 75보다 크다
