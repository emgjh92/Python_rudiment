# %%
print("hello world!!!")
# Out:
# hello world!!!

# %% [markdown]
# 텍스트

# %%
'''
전체주석....
(사실 진짜 주석은 아니고 그냥 문자열인데 대다수의 책에서 주석이라 표현)
'''

"안녕하세요"
print('안녕하세요')

a='''안녕하
세요'''

a
# Out:
# 안녕하세요
# '안녕하\n세요'

# %%
a=10
print(a)
a
# Out:
# 10
# 10

# %%
#변수....!!!
a=10
b=20
c="안녕하세요"
d=1.1111

a="반갑습니다."
print(a)

a=10

b = type(a)
b


print(type(b))
# Out:
# 반갑습니다.
# <class 'type'>

# %%
#print 함수 활용
print("안녕하세요")

print("100")

print(" 안녕%s하세요 %d 반갑 %d 습니다.%f" % ("qqq",100,200,0.001))

print("%d" % (100+100))

print("%d" % (100))

print("%d / %d = %d" % (100,200,0.5))

print("%d" %(10))
print("%x" %(10))
print("%o" %(10))
# Out:
# 안녕하세요
# 100
#  안녕qqq하세요 100 반갑 200 습니다.0.001000
# 200
# 100
# 100 / 200 = 0
# 10
# a
# 12

# %%
#print() 함수를 사용한 깔끔한 출력
print("%7d %7d %7d" %(10,20,30))
print("%7d %7d %7d" %(111111,2222,3333))

print("a            b            c")
# Out:
#      10      20      30
#  111111    2222    3333
# a            b            c

# %%
#한칸 내리고 출력하기
print("안녕하세요 \t 반갑습니다")
# \t = 탭키
# Out:
# 안녕하세요 	 반갑습니다
